# %% [markdown]
# ![logo_itq](img/logo-itq.jpeg)
# ## Tercer Modulo-Python, Tipos de Datos - Data Types
# ![logo_python](img/logo-python.jpeg)<br>
# *Nixon Malquin*
#
#
#
# # Introdución a Python
# Python es un lenguaje de programación de alto nivel. <br>
# Orientado a objetos

# %%
#Impresión en pantalla "Hola Mundo" en python
#Lo que esta dentro de las comillas se llma cadena de caracteres o string
print("Hola mundo Python")
# Out:
# hola mundo Python

# %%
print("Nixon Malquin")
# Out:
# Nixon Malquin
