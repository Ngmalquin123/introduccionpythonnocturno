# %% [markdown]
# # Examen Tercer Parcial

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 01 - 1.25pt
# - Escribir un generador que genere todos los factores de un número. Un factor es un número natural que puede dividir exactamente a otro número.

# %%
# Your solution HERE !!!!

def factor_generator(number):
    result=[]
    for i in range(1,number+1):
        if number % i== 0:
            result.append(i)
    return iter(result)

# %%
# Test Use Case
number = 1000
expected_factors = [1, 2, 4, 5, 8, 10, 20, 25, 40, 50, 100, 125, 200, 250, 500, 1000]

gen = factor_generator(number) # This calls tour function factor_generator
output = [next(gen) for n in range(len(expected_factors))]

print(expected_factors)
print(output)

assert(expected_factors == output)  # This will fail if the element is not found correctly
# Out:
# [1, 2, 4, 5, 8, 10, 20, 25, 40, 50, 100, 125, 200, 250, 500, 1000]
# [1, 2, 4, 5, 8, 10, 20, 25, 40, 50, 100, 125, 200, 250, 500, 1000]

# %% [markdown]
# ## 02 - 1.25pt
#
# - Escribe una función que reciba un DataFrame, que le agregue una nueva columna llamada ‘Promedio’ que sea el promedio de sus columnas Luego, filtre las filas donde el valor de ‘Promedio’ sea mayor que 5 y lo ordene por la columna ‘Promedio’ en orden descendente.

# %%
# Your solution HERE !!!!
def func_mean(df):
   
    df['Promedio']=df.mean(axis=1)
    df= df[ df['Promedio'] >5]
    df=df.sort_values(by='Promedio', ascending=False)
    df=df.reset_index(drop=True)
    return df

# %%
# Test Use Case
source_dataframe = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 7, 6], 'C': [7, 12, 9]})
expected_dataframe = pd.DataFrame({'A': [2, 3], 'B': [7, 6], 'C': [12, 9], 'Promedio':[7.0, 6.0]})

output = func_mean(source_dataframe) # This calls your function named func_mean

display(expected_dataframe)
display(output)

assert(expected_dataframe.equals(output)) # This will fail if the dataframe is wrong
# Out:
#    A  B   C  Promedio
# 0  2  7  12       7.0
# 1  3  6   9       6.0
#    A  B   C  Promedio
# 0  2  7  12       7.0
# 1  3  6   9       6.0

# %% [markdown]
# ## 03 - 1.25pt
#
# - Dado el siguiente DataFrame, reemplaza los valores nulos en la columna ‘B’ con la media de los valores de esa columna. Luego, normaliza los valores de la columna ‘C’ para que estén en el rango [0, 1].

# %%
# Your solution HERE !!!!

def func(df):
    df['B']= df['B'].fillna(df['B'].mean())

    min_c= df['C'].min()
    max_c= df['C'].max()
    df['C'] = (df['C']- min_c)/ (max_c -min_c)
    return df

# %%
# Test Use Case
source_dataframe = pd.DataFrame({'A': [1, 2, 3], 'B': [4, None, 6], 'C': [7, 8, 9]})
expected_dataframe = pd.DataFrame({'A': [1, 2, 3], 'B': [4.0, 5.0, 6.0], 'C': [0, 0.5, 1.0]})

output = func(source_dataframe) # This calls your function named func

display(expected_dataframe)
display(output)

assert(expected_dataframe.equals(output)) # This will fail if the dataframe is wrong
# Out:
#    A    B    C
# 0  1  4.0  0.0
# 1  2  5.0  0.5
# 2  3  6.0  1.0
#    A    B    C
# 0  1  4.0  0.0
# 1  2  5.0  0.5
# 2  3  6.0  1.0

# %% [markdown]
# ## 04 - 1.25pt
# - Utilizando Matplotlib y Seaborn, crea un gráfico de dispersión (scatter plot) que muestre la relación entre las columnas ‘A’ y ‘B’ del siguiente DataFrame. Además, ajusta una línea de regresión a los datos.

# %%
# Data
df = pd.DataFrame({'A': [1, 2, 3, 4, 5], 'B': [5.4, 4.1, 2.8, 1.9, 0.7]})

# %%
# Your solution HERE !!!!

# %% [markdown]
# # 5 - 5 pt
#
# - Adjunto al notebook se puede encontrar un fichero 'ine_paro_exam.csv' que contiene datos del INE referentes al paro en España. Las columnas son las siguientes:
#   - Sexo, los datos de esa fila se refieren a hombres, mujeres o ambos sexos
#   - Provincias, los datos de esa fila son totales para todo el pais, o de alguna provincia en particular
#   - Tasas, que tipo de tasa representa el valor de la fila, es de actividad, paro o empleo.
#   - Periodo, a que periodo de tiempo aplica el dato, año y trimestre
#   - Total, el dato de la tasa
# - Se pide lo siguiente:
#   - 01 - Cargar los datos en un dataframe de Pandas.
#   - 02 - Realize un análisis descriptivo de los datos y haga un recuento de datos por cada valor único de la columna "Tasas".
#   - 03 - ¿Cuantos valores nulos hay por columna? Eliminar las filas que tienen nulo en la columna "Total" y muestre el número de columnas tras esta operación.
#   - 04 - Obtener la media de la tasa de paro por trimestre, en la provincia de Zaragoza y para ambos sexos.
#   - 05 - Representar una figura con tres gráficas con tres diferentes tasas el total nacional y ambos sexos, de manera que en cada subfigura se represente la evolución por trimestre de cada año (cada año se considera una linea con un color diferente). Se adjunta al examen imagen de muestra de lo solicitado: ![tasas](tasasportrimestre.png)

# %%
# Your solution HERE !!!!
# 01 - Cargar los datos en un dataframe de Pandas.


# 1. Cargar datos

df=pd.read_csv('ine_paro_exam.csv', sep='|')
display(df)
# Out:
#               Sexo      Provincias                           Tasas Periodo  \
# 0      Ambos sexos  Total Nacional               Tasa de actividad  2023T1
# 1      Ambos sexos  Total Nacional               Tasa de actividad  2022T4
# 2      Ambos sexos  Total Nacional               Tasa de actividad  2022T3
# 3      Ambos sexos  Total Nacional               Tasa de actividad  2022T2
# 4      Ambos sexos  Total Nacional               Tasa de actividad  2022T1
# ...            ...             ...                             ...     ...
# 40540      Mujeres      52 Melilla  Tasa de empleo de la población  2003T1
# 40541      Mujeres      52 Melilla  Tasa de empleo de la población  2002T4
# 40542      Mujeres      52 Melilla  Tasa de empleo de la población  2002T3
# 40543      Mujeres      52 Melilla  Tasa de empleo de la población  2002T2
# 40544      Mujeres      52 Melilla  Tasa de empleo de la población  2002T1
#
#        Total
# 0      58.55
# 1      58.52
# 2      58.86
# 3      58.71
# 4      58.50
# ...      ...
# 40540  30.09
# 40541  29.64
# 40542  31.53
# 40543  30.03
# 40544  27.38
#
# [40545 rows x 5 columns]

# %%
# Your solution HERE !!!!
# 02 - Realize un análisis descriptivo de los datos y haga un recuento de datos por cada valor único de la columna "Tasas".
print('Analisis Descriptivo')
display(df.describe(include='all'))

print("Recuento por Tasas")
print(df['Tasas'].value_counts())
# Out:
# Analisis Descriptivo
#                Sexo      Provincias              Tasas Periodo         Total
# count         40545           40545              40545   40495  40445.000000
# unique            3              53                  3      85           NaN
# top     Ambos sexos  Total Nacional  Tasa de actividad  2023T1           NaN
# freq          13515             765              13515     477           NaN
# mean            NaN             NaN                NaN     NaN     40.265056
# std             NaN             NaN                NaN     NaN     19.330065
# min             NaN             NaN                NaN     NaN      0.000000
# 25%             NaN             NaN                NaN     NaN     21.310000
# 50%             NaN             NaN                NaN     NaN     45.540000
# 75%             NaN             NaN                NaN     NaN     55.770000
# max             NaN             NaN                NaN     NaN     79.000000
# Recuento por Tasas
# Tasas
# Tasa de actividad                 13515
# Tasa de paro de la población      13515
# Tasa de empleo de la población    13515
# Name: count, dtype: int64

# %%
# Your solution HERE !!!!
# 03 - ¿Cuantos valores nulos hay por columna? Eliminar las filas que tienen nulo en la columna "Total" 
#y muestre el número de columnas tras esta operación.
# Contar valores nulos por columna

print(df.isnull().sum())

df = df.dropna(subset=['Total'])
print('columnas despues de la operación')
display(df.shape[1])
# Out:
# Sexo           0
# Provincias     0
# Tasas          0
# Periodo       50
# Total          0
# dtype: int64
# columnas despues de la operación
# 5

# %%
# Your solution HERE !!!!
# 04 - Obtener la media de la tasa de paro por trimestre, en la provincia de Zaragoza y para ambos sexos.
filtro_zaragoza = df[
    (df['Provincias'].str.contains('Zaragoza', na=False)) & 
    (df['Tasas'].str.contains('paro', case=False)) & 
    (df['Sexo'] == 'Ambos sexos')
]

media_zgz = filtro_zaragoza['Total'].mean()
print(f"La media de la tasa  en Zaragoza (Ambos sexos) es: {media_zgz}")
# Out:
# La media de la tasa  en Zaragoza (Ambos sexos) es: 12.06870588235294

# %%
# Your solution HERE !!!!
# 05 - Representar una figura con tres gráficas con tres diferentes tasas el total nacional y ambos sexos, 
#de manera que en cada subfigura se represente la evolución por trimestre de cada año (cada año se considera una linea con un color diferente).


df['Año'] = df['Periodo'].str[:4]
df['Trimestre'] = df['Periodo'].str[-2:]


df_nacional = df[(df['Provincias'].str.contains('Total Nacional')) & 
                 (df['Sexo'] == 'Ambos sexos')]


fig, axes = plt.subplots(1, 3, figsize=(18, 5))
tasas_a_graficar = df_nacional['Tasas'].unique()[:3] 

for i, tasa in enumerate(tasas_a_graficar):

    datos_tasa = df_nacional[df_nacional['Tasas'] == tasa]
    
    tabla_pivot = datos_tasa.pivot(index='Trimestre', columns='Año', values='Total')
    
    tabla_pivot.plot(ax=axes[i], marker='o')
    
    axes[i].set_title(f'Tasa: {tasa}')
    axes[i].set_ylabel('Porcentaje')
    axes[i].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
